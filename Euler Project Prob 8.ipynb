# %%
import os
os.chdir("C:/Users/yoonh/OneDrive/바탕 화면/coding the matrix")
material = open('prob 8.txt', 'r')

# %%
material_read = material.read()

# %%
material_read
# Out:
# '73167176531330624919225119674426574742355349194934\n96983520312774506326239578318016984801869478851843\n85861560789112949495459501737958331952853208805511\n12540698747158523863050715693290963295227443043557\n66896648950445244523161731856403098711121722383113\n62229893423380308135336276614282806444486645238749\n30358907296290491560440772390713810515859307960866\n70172427121883998797908792274921901699720888093776\n65727333001053367881220235421809751254540594752243\n52584907711670556013604839586446706324415722155397\n53697817977846174064955149290862569321978468622482\n83972241375657056057490261407972968652414535100474\n82166370484403199890008895243450658541227588666881\n16427171479924442928230863465674813919123162824586\n17866458359124566529476545682848912883142607690042\n24219022671055626321111109370544217506941658960408\n07198403850962455444362981230987879927244284909188\n84580156166097919133875499200524063689912560717606\n05886116467109405077541002256983155200055935729725\n716362695
# ...

# %%
material_read = material_read.replace("\n", "")
material_read
# Out:
# '...'

# %%
len(material_read)
# Out:
# 1000

# %%
i = 0
new_list = []
while True:
    new_list.append(material_read[i:i+5])
    i += 1
    if i == len(material_read)-4:
        break

new_list
# Out:
# ['73167',
#  '31671',
#  '16717',
#  '67176',
#  '71765',
#  '17653',
#  '76531',
#  '65313',
#  '53133',
#  '31330',
#  '13306',
#  '33062',
#  '30624',
#  '06249',
#  '62491',
#  '24919',
#  '49192',
#  '91922',
#  '19225',
#  '92251',
#  '22511',
#  '25119',
#  '51196',
#  '11967',
#  '19674',
#  '96744',
#  '67442',
#  '74426',
#  '44265',
#  '42657',
#  '26574',
#  '65747',
#  '57474',
#  '74742',
#  '47423',
#  '74235',
#  '42355',
#  '23553',
#  '35534',
#  '55349',
#  '53491',
#  '34919',
#  '49194',
#  '91949',
#  '19493',
#  '94934',
#  '49349',
#  '93496',
#  '34969',
#  '49698',
#  '96983',
#  '69835',
#  '98352',
#  '83520',
#  '35203',
#  '52031',
#  '20312',
#  '03127',
#  '31277',
#  '12774',
#  '27745',
#  '77450',
#  '74506',
#  '45063',
#  '50632',
#  '06326',
#  '63262',
#  '32623',
#  '26239',
#  '62395',
#  '23957',
#  '39578',
#  '95783',
#  '57831',
#  '78318',
#  '83180',
#  '31801',
#  '18016',
#  '80169',
#  '01698',
#  '16984',
#  '69848',
#  '98480',
# ...

# %%
final = []
for i in new_list:
    final.append(int(i[0])*int(i[1])*int(i[2])*int(i[3])*int(i[4]))
    print('')

final
# Out:
# [882,
#  126,
#  294,
#  1764,
#  1470,
#  630,
#  630,
#  270,
#  135,
#  0,
#  0,
#  0,
#  0,
#  0,
#  432,
#  648,
#  648,
#  324,
#  180,
#  180,
#  20,
#  90,
#  270,
#  378,
#  1512,
#  6048,
#  1344,
#  1344,
#  960,
#  1680,
#  1680,
#  5880,
#  3920,
#  1568,
#  672,
#  840,
#  600,
#  450,
#  900,
#  2700,
#  540,
#  972,
#  1296,
#  2916,
#  972,
#  3888,
#  3888,
#  5832,
#  5832,
#  15552,
#  11664,
#  6480,
#  2160,
#  0,
#  0,
#  0,
#  0,
#  0,
#  294,
#  392,
#  1960,
#  0,
#  0,
#  0,
#  0,
#  0,
#  432,
#  216,
#  648,
#  1620,
#  1890,
#  7560,
#  7560,
#  840,
#  1344,
#  0,
#  0,
#  0,
#  0,
#  0,
#  1728,
#  13824,
#  0,
#  0,
#  0,
#  0,
#  0,
#  1728,
#  12096,
#  12096,
#  16128,
#  8960,
#  2240,
#  2560,
#  1280,
#  480,
#  768,
#  3840,
#  3840,
#  5760,
#  1920,
#  1200,
#  1440,
#  0,
#  0,
#  0,
#  0,
#  0,
#  504,
#  144,
#  162,
#  72,
#  648,
#  2592,
#  11664,
#  6480,
#  6480,
#  3600,
#  8100,
#  4500,
#  0,
#  0,
#  0,
#  0,
#  0,
#  1323,
# ...

# %%
max(final)
# Out:
# 40824

# %%
min(final)
# Out:
# 0
